# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='Trump' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[42.359121,-71.093260] 
# MIT
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=10

# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:05:47 +0000 2017',
#   'entities': {'hashtags': [{'indices': [110, 118], 'text': 'TYTLive'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 4444856237,
#      'id_str': '4444856237',
#      'indices': [3, 19],
#      'name': '🇪🇸Gaby Mérida🇺🇸',
#      'screen_name': 'ThatSpanishLady'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839250754410070016,
#   'id_str': '839250754410070016',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 23:04:22 +0000 2017',
#    'entities': {'hashtags': [{'indices': [89, 97], 'text': 'TYTLive'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 3,
#    'favorited': False,
#    'geo': None,
#    'id': 839250400133918720,
#    'id_str': '839250400133918720',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Alex Jones is right about one thing when it comes to Trump. It's not Human intelligence. #TYTLive",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Dec 11 04:48:37 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Spaniard by birth. Bostonian by choice. Dramaturg by profession. Incorrigible foodie by night. General aviation pilot. TYT junkie. Sometime STO player (& RPer)',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3849,
#     'follow_request_sent': None,
#     'followers_count': 801,
#     'following': None,
#     'friends_count': 671,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 4444856237,
#     'id_str': '4444856237',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 24,
#     'location': 'Boston',
#     'name': '🇪🇸Gaby Mérida🇺🇸',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4444856237/1485719397',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/811678206847778818/N49v0BTq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/811678206847778818/N49v0BTq_normal.jpg',
#     'profile_link_color': '9E030B',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'ThatSpanishLady',
#     'statuses_count': 8374,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "RT @ThatSpanishLady: Alex Jones is right about one thing when it comes to Trump. It's not Human intelligence. #TYTLive",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 07 01:35:21 +0000 2016',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "An angry, opinionated person getting his PhD in Atmospheric Chemistry.  I'll probably discuss a variety of issues",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 7576,
#    'follow_request_sent': None,
#    'followers_count': 197,
#    'following': None,
#    'friends_count': 442,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 717888458337824768,
#    'id_str': '717888458337824768',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 9,
#    'location': '',
#    'name': 'Ben',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/808773850158678017/GT4Gwcae_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/808773850158678017/GT4Gwcae_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'BenjaminChemist',
#    'statuses_count': 7310,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:05:44 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/MaxineWaters/s…',
#      'expanded_url': 'https://twitter.com/MaxineWaters/status/839248867061350401',
#      'indices': [81, 104],
#      'url': 'https://t.co/WM4tHs1n13'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839250742636589057,
#   'id_str': '839250742636589057',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 22:58:17 +0000 2017',
#    'entities': {'hashtags': [{'indices': [51, 63], 'text': 'KremlinKlan'}],
#     'symbols': [],
#     'urls': [{'display_url': 'politi.co/2lBACUP',
#       'expanded_url': 'http://politi.co/2lBACUP',
#       'indices': [64, 87],
#       'url': 'https://t.co/McLCfJc0AR'}],
#     'user_mentions': []},
#    'favorite_count': 218,
#    'favorited': False,
#    'geo': None,
#    'id': 839248867061350401,
#    'id_str': '839248867061350401',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 144,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Trump campaign approved adviser's trip to Moscow...#KremlinKlan https://t.co/McLCfJc0AR",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 30 15:17:45 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Proudly serving the people of California's 43rd District in Congress. Ranking Member of the House Financial Services Committee (@FSCDems).",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'waters.house.gov',
#         'expanded_url': 'http://waters.house.gov',
#         'indices': [0, 22],
#         'url': 'http://t.co/ODIbQQR7g9'}]}},
#     'favourites_count': 616,
#     'follow_request_sent': None,
#     'followers_count': 149977,
#     'following': None,
#     'friends_count': 610,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 36686040,
#     'id_str': '36686040',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2513,
#     'location': 'Los Angeles/Washington, D.C.',
#     'name': 'Maxine Waters',
#     'notifications': None,
#     'profile_background_color': 'EBEBEB',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/36686040/1434477112',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000824906688/2254719201496ac256c01b484a32d48c_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000824906688/2254719201496ac256c01b484a32d48c_normal.jpeg',
#     'profile_link_color': '990000',
#     'profile_sidebar_border_color': 'DFDFDF',
#     'profile_sidebar_fill_color': 'F3F3F3',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MaxineWaters',
#     'statuses_count': 1962,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/ODIbQQR7g9',
#     'utc_offset': -28800,
#     'verified': True}},
#   'quoted_status_id': 839248867061350401,
#   'quoted_status_id_str': '839248867061350401',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'Thanks Congresswoman for being one of the few voices opposing Trump in Congress. https://t.co/WM4tHs1n13',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Oct 09 03:58:32 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Geographer.  Love Wilderness and Montana. Enjoy working on complex problems using interdisciplinary teams.  Comments are my own.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 21697,
#    'follow_request_sent': None,
#    'followers_count': 3904,
#    'following': None,
#    'friends_count': 2837,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 387474635,
#    'id_str': '387474635',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 156,
#    'location': 'Montana, USA',
#    'name': 'Alex Philp',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000021302934/0e65f3e499f1ca0ca4e3d6b733fa9644.gif',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000021302934/0e65f3e499f1ca0ca4e3d6b733fa9644.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/387474635/1457668291',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3288825050/fb3d466a05cdba985d6fd5b7fb01ffd0_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3288825050/fb3d466a05cdba985d6fd5b7fb01ffd0_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BigDataAlex',
#    'statuses_count': 29458,
#    'time_zone': 'America/Denver',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:05:36 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'politico.com/story/2017/03/…',
#      'expanded_url': 'http://www.politico.com/story/2017/03/carter-page-russia-trip-trump-corey-lewandowski-235784',
#      'indices': [49, 72],
#      'url': 'https://t.co/IhDcAWu9hB'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839250711342944256,
#   'id_str': '839250711342944256',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Boston, MA',
#    'id': '67b98f17fdcf20be',
#    'name': 'Boston',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "Team Trump is the gang that can't lie straight.  https://t.co/IhDcAWu9hB",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Sep 28 14:04:36 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '@Mills_PR principal. Communicator. Crisis manager. Public affairs. Northern know-it-all with open mind. Look white but just a human being. Call out BS? Yes',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3984,
#    'follow_request_sent': None,
#    'followers_count': 508,
#    'following': None,
#    'friends_count': 1458,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 381532271,
#    'id_str': '381532271',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 21,
#    'location': 'Boston',
#    'name': '(((ScottFarmelant)))',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/337936804/Newspaper_roll.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/337936804/Newspaper_roll.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/381532271/1484612828',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/817090089482338304/vDVlmxvi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817090089482338304/vDVlmxvi_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '0E064D',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ScottFarmelant',
#    'statuses_count': 9966,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:05:22 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 94391895,
#      'id_str': '94391895',
#      'indices': [3, 14],
#      'name': 'Here & Now',
#      'screen_name': 'hereandnow'},
#     {'id': 151444950,
#      'id_str': '151444950',
#      'indices': [49, 59],
#      'name': 'Susan Davis',
#      'screen_name': 'DaviSusan'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839250652815581184,
#   'id_str': '839250652815581184',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 23:03:01 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'n.pr/2myCaOJ',
#       'expanded_url': 'http://n.pr/2myCaOJ',
#       'indices': [111, 134],
#       'url': 'https://t.co/hs8tvOvR3O'}],
#     'user_mentions': [{'id': 151444950,
#       'id_str': '151444950',
#       'indices': [33, 43],
#       'name': 'Susan Davis',
#       'screen_name': 'DaviSusan'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 839250059057209344,
#    'id_str': '839250059057209344',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'On the American Health Care Act, @DaviSusan explains why President Trump’s role in the debate will be crucial: https://t.co/hs8tvOvR3O',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Dec 03 19:08:58 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "Here & Now is @NPR's midday news magazine, produced at @WBUR and hosted by @hereandnowrobin and @jeremyhobson.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'hereandnow.org',
#         'expanded_url': 'http://hereandnow.org',
#         'indices': [0, 22],
#         'url': 'http://t.co/8IXzFYltZj'}]}},
#     'favourites_count': 1372,
#     'follow_request_sent': None,
#     'followers_count': 25676,
#     'following': None,
#     'friends_count': 15789,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 94391895,
#     'id_str': '94391895',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 835,
#     'location': 'Boston',
#     'name': 'Here & Now',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/94391895/1372600928',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/755812477632442368/pqcMMhFe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/755812477632442368/pqcMMhFe_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'hereandnow',
#     'statuses_count': 26301,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/8IXzFYltZj',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @hereandnow: On the American Health Care Act, @DaviSusan explains why President Trump’s role in the debate will be crucial: https://t.co…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 17 02:14:00 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#AfroLatinx. Tweets are my own! RTs ≠ endorsements. #DouglassCommonwealth 💪🏾',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 17633,
#    'follow_request_sent': None,
#    'followers_count': 2831,
#    'following': None,
#    'friends_count': 3166,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 267510129,
#    'id_str': '267510129',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 79,
#    'location': 'Douglass Commonwealth',
#    'name': 'Annette Raveneau',
#    'notifications': None,
#    'profile_background_color': 'C1C3EB',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000160981062/2YMRqunE.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000160981062/2YMRqunE.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/267510129/1488301643',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/738045509353496581/O4sDs0Za_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/738045509353496581/O4sDs0Za_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AnnetteRAVENEAU',
#    'statuses_count': 31166,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:05:10 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'ow.ly/jNQp309FLk2',
#      'expanded_url': 'http://ow.ly/jNQp309FLk2',
#      'indices': [85, 108],
#      'url': 'https://t.co/5RsxGl0lJQ'}],
#    'user_mentions': [{'id': 807095,
#      'id_str': '807095',
#      'indices': [4, 12],
#      'name': 'The New York Times',
#      'screen_name': 'nytimes'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839250602047770624,
#   'id_str': '839250602047770624',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': 'via @nytimes: Trump’s New Travel Ban Blocks Migrants From Six Nations, Sparing Iraq. https://t.co/5RsxGl0lJQ',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Feb 20 03:08:07 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Connecting clinical social workers to their profession in a rich and dynamic way.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'acswa.org',
#        'expanded_url': 'http://acswa.org',
#        'indices': [0, 23],
#        'url': 'https://t.co/qI4VBZYGz7'}]}},
#    'favourites_count': 293,
#    'follow_request_sent': None,
#    'followers_count': 1335,
#    'following': None,
#    'friends_count': 475,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 254831104,
#    'id_str': '254831104',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 61,
#    'location': 'Boston, MA',
#    'name': 'ACSWA',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/353865233/ACSWAtwitter_bg2.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/353865233/ACSWAtwitter_bg2.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/254831104/1414515396',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/525712968927805440/sldtyH-j_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/525712968927805440/sldtyH-j_normal.png',
#    'profile_link_color': '1440A1',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '828282',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'acswa',
#    'statuses_count': 7429,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/qI4VBZYGz7',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:04:52 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/nypost/status/…',
#      'expanded_url': 'https://twitter.com/nypost/status/839250150363172867',
#      'indices': [21, 44],
#      'url': 'https://t.co/f9YA5OQAcs'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 839250526843858945,
#   'id_str': '839250526843858945',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 23:03:23 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'nyp.st/2meuFKJ',
#       'expanded_url': 'http://nyp.st/2meuFKJ',
#       'indices': [117, 140],
#       'url': 'https://t.co/GhMBcZQFQI'}],
#     'user_mentions': []},
#    'favorite_count': 11,
#    'favorited': False,
#    'geo': None,
#    'id': 839250150363172867,
#    'id_str': '839250150363172867',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 10,
#    'retweeted': False,
#    'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#    'text': 'Op-ed: The investigation of Russian interference in the US election could turn into a big headache for the democrats https://t.co/GhMBcZQFQI',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 18 19:46:36 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Breaking news & features from The New York Post, powered 24/7 by our Web team. Follow your favorite celebs at @PageSix & favorite teams at @nypostsports.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nypost.com',
#         'expanded_url': 'http://www.nypost.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/hKwnInDOKi'}]}},
#     'favourites_count': 2226,
#     'follow_request_sent': None,
#     'followers_count': 1197398,
#     'following': None,
#     'friends_count': 12074,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 17469289,
#     'id_str': '17469289',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 17022,
#     'location': 'New York, NY',
#     'name': 'New York Post',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/652143411756171265/9GLOzw2i.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/652143411756171265/9GLOzw2i.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17469289/1444326181',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/525710590900047873/734Kx0zX_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/525710590900047873/734Kx0zX_normal.jpeg',
#     'profile_link_color': 'CC3333',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'nypost',
#     'statuses_count': 103856,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/hKwnInDOKi',
#     'utc_offset': -18000,
#     'verified': True}},
#   'quoted_status_id': 839250150363172867,
#   'quoted_status_id_str': '839250150363172867',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Byline: Donald Trump https://t.co/f9YA5OQAcs',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri May 28 16:57:15 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '@ListenToBrunch Recommendation Whisperer / Demander. Jay-Z owes me $50,000.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'canihave50grandjayz.tumblr.com',
#        'expanded_url': 'http://canihave50grandjayz.tumblr.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/uP8w15Zv7w'}]}},
#    'favourites_count': 22215,
#    'follow_request_sent': None,
#    'followers_count': 3398,
#    'following': None,
#    'friends_count': 994,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 149188258,
#    'id_str': '149188258',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 119,
#    'location': 'Boston, MA, ',
#    'name': 'Jeff Israel 📎',
#    'notifications': None,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/149188258/1483583021',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/831550197121613826/xkSU68f0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831550197121613826/xkSU68f0_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'A8C7F7',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'jeffisrael25',
#    'statuses_count': 67511,
#    'time_zone': 'Atlantic Time (Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/uP8w15Zv7w',
#    'utc_offset': -14400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:04:46 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 14090906,
#      'id_str': '14090906',
#      'indices': [3, 12],
#      'name': 'Chris Wysopal',
#      'screen_name': 'WeldPond'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839250498838540289,
#   'id_str': '839250498838540289',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 7,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 20:13:12 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/839207326431199232',
#       'indices': [112, 135],
#       'url': 'https://t.co/M158Be4IOP'}],
#     'user_mentions': []},
#    'favorite_count': 14,
#    'favorited': False,
#    'geo': None,
#    'id': 839207326431199232,
#    'id_str': '839207326431199232',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 7,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Educating consumers is not going to solve cybercrime. We need vendors to deliver secure software and services.… https://t.co/M158Be4IOP',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Mar 06 19:46:55 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Co-founder, CTO of Veracode. Former L0pht security researcher, developer of L0phtCrack and Netcat for Windows. Reaping negative entropy. #appsec #devsecops',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'infoworld.com/author/Chris-W…',
#         'expanded_url': 'http://www.infoworld.com/author/Chris-Wysopal/',
#         'indices': [0, 23],
#         'url': 'https://t.co/fTKLUJsaqW'}]}},
#     'favourites_count': 973,
#     'follow_request_sent': None,
#     'followers_count': 35367,
#     'following': None,
#     'friends_count': 687,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 14090906,
#     'id_str': '14090906',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1651,
#     'location': 'Boston, MA',
#     'name': 'Chris Wysopal',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14090906/1485544635',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/613065292709801985/LapqXdxh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/613065292709801985/LapqXdxh_normal.jpg',
#     'profile_link_color': '8B4513',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'WeldPond',
#     'statuses_count': 19102,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/fTKLUJsaqW',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @WeldPond: Educating consumers is not going to solve cybercrime. We need vendors to deliver secure software and services.\nhttps://t.co/d…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun May 03 01:34:37 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "Writer and blogger at @Veracode. Formerly at @NakedSecurity. Interests: politics, tech, journalism, sports. Views are my own, not employer's.",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2983,
#    'follow_request_sent': None,
#    'followers_count': 1379,
#    'following': None,
#    'friends_count': 2200,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 37332800,
#    'id_str': '37332800',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 92,
#    'location': 'Massachusetts',
#    'name': 'John Zorabedian',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37332800/1483967045',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834103187393032192/qzlDhsNH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834103187393032192/qzlDhsNH_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JohnZorabedian',
#    'statuses_count': 22285,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:04:34 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/839250449421099008',
#      'indices': [105, 128],
#      'url': 'https://t.co/98SGpEbHem'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 839250449421099008,
#   'id_str': '839250449421099008',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "Shouldn't he be working or maybe, um, governing? Trump tweets for 2 hours today while watching Fox News… https://t.co/98SGpEbHem",
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Dec 28 03:30:06 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Nuts about data, social media & analytics, the arts, history & design. Information Architect & Strategist. Designer. Some social advocacy & nonprofit work.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'jaynedutra.com',
#        'expanded_url': 'http://jaynedutra.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/K9z7INxzsM'}]}},
#    'favourites_count': 3823,
#    'follow_request_sent': None,
#    'followers_count': 411,
#    'following': None,
#    'friends_count': 1158,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 2265288152,
#    'id_str': '2265288152',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 32,
#    'location': 'Medford',
#    'name': 'Jayne Dutra',
#    'notifications': None,
#    'profile_background_color': '352726',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2265288152/1483371024',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/440945377764593664/of6hvjtM_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/440945377764593664/of6hvjtM_normal.png',
#    'profile_link_color': '5C0CE6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '99CC33',
#    'profile_text_color': '3E4415',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JayneDutra',
#    'statuses_count': 3666,
#    'time_zone': 'Arizona',
#    'translator_type': 'none',
#    'url': 'http://t.co/K9z7INxzsM',
#    'utc_offset': -25200,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:04:24 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/charles_gaba/s…',
#      'expanded_url': 'https://twitter.com/charles_gaba/status/839248259608625154',
#      'indices': [72, 95],
#      'url': 'https://t.co/zQYAZLfSxd'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 839250409449488385,
#   'id_str': '839250409449488385',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 22:55:52 +0000 2017',
#    'entities': {'hashtags': [{'indices': [0, 11], 'text': 'ACASignups'},
#      {'indices': [122, 126], 'text': 'ACA'},
#      {'indices': [127, 137], 'text': 'TrumpCare'}],
#     'symbols': [],
#     'urls': [{'display_url': 'acasignups.net/17/03/07/molin…',
#       'expanded_url': 'http://acasignups.net/17/03/07/molina-trumpublicare-will-force-us-jack-rates-least-30-all-itself',
#       'indices': [98, 121],
#       'url': 'https://t.co/RceOzhUG26'}],
#     'user_mentions': []},
#    'favorite_count': 5,
#    'favorited': False,
#    'geo': None,
#    'id': 839248259608625154,
#    'id_str': '839248259608625154',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': {'attributes': {},
#     'bounding_box': {'coordinates': [[[-83.325363, 42.529187],
#        [-83.206336, 42.529187],
#        [-83.206336, 42.620953],
#        [-83.325363, 42.620953]]],
#      'type': 'Polygon'},
#     'contained_within': [],
#     'country': 'United States',
#     'country_code': 'US',
#     'full_name': 'Bloomfield Township, MI',
#     'id': '76ad816c29482c9b',
#     'name': 'Bloomfield Township',
#     'place_type': 'city',
#     'url': 'https://api.twitter.com/1.1/geo/id/76ad816c29482c9b.json'},
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://tapbots.com/software/tweetbot/mac" rel="nofollow">Tweetbot for Mac</a>',
#    'text': '#ACASignups Fun With Math: a 30% surcharge on top of a 30% rate hike = a 69% effective rate hike! https://t.co/RceOzhUG26 #ACA #TrumpCare',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Mar 23 00:05:23 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Web Developer at https://t.co/VJgARxWKQ2 Obamacare Tracker at https://t.co/E2uQBKy14b',
#     'entities': {'description': {'urls': [{'display_url': 'Brainwrap.com',
#         'expanded_url': 'http://Brainwrap.com',
#         'indices': [17, 40],
#         'url': 'https://t.co/VJgARxWKQ2'},
#        {'display_url': 'ACASignups.net',
#         'expanded_url': 'http://ACASignups.net',
#         'indices': [62, 85],
#         'url': 'https://t.co/E2uQBKy14b'}]},
#      'url': {'urls': [{'display_url': 'acasignups.net',
#         'expanded_url': 'http://www.acasignups.net',
#         'indices': [0, 23],
#         'url': 'https://t.co/jheWZfCvek'}]}},
#     'favourites_count': 118512,
#     'follow_request_sent': None,
#     'followers_count': 14728,
#     'following': None,
#     'friends_count': 1073,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 25911963,
#     'id_str': '25911963',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 458,
#     'location': 'Bloomfield Township, MI',
#     'name': '☪️ Charles Gaba ✡️',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25911963/1480178331',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/723145771663511552/rfElo8U0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/723145771663511552/rfElo8U0_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'charles_gaba',
#     'statuses_count': 141598,
#     'time_zone': 'Quito',
#     'translator_type': 'none',
#     'url': 'https://t.co/jheWZfCvek',
#     'utc_offset': -18000,
#     'verified': True}},
#   'quoted_status_id': 839248259608625154,
#   'quoted_status_id_str': '839248259608625154',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'You know you just confused every Trump supporter out there woth this... https://t.co/zQYAZLfSxd',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jul 18 17:43:24 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Progressive Democrat, Kossack, PhD Boston-area UU mom of two. Believes in equality for all Amendments not just the 2nd. I #Resist',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 939,
#    'follow_request_sent': None,
#    'followers_count': 754,
#    'following': None,
#    'friends_count': 873,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 15483858,
#    'id_str': '15483858',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 46,
#    'location': 'Boston, MA',
#    'name': 'Kelly',
#    'notifications': None,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/824763077916778497/mDBV-kEl_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/824763077916778497/mDBV-kEl_normal.jpg',
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': '5ED4DC',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'brilligt',
#    'statuses_count': 3867,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 23:04:22 +0000 2017',
#   'entities': {'hashtags': [{'indices': [89, 97], 'text': 'TYTLive'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 3,
#   'favorited': False,
#   'geo': None,
#   'id': 839250400133918720,
#   'id_str': '839250400133918720',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "Alex Jones is right about one thing when it comes to Trump. It's not Human intelligence. #TYTLive",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Dec 11 04:48:37 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Spaniard by birth. Bostonian by choice. Dramaturg by profession. Incorrigible foodie by night. General aviation pilot. TYT junkie. Sometime STO player (& RPer)',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3849,
#    'follow_request_sent': None,
#    'followers_count': 801,
#    'following': None,
#    'friends_count': 671,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 4444856237,
#    'id_str': '4444856237',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 24,
#    'location': 'Boston',
#    'name': '🇪🇸Gaby Mérida🇺🇸',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4444856237/1485719397',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/811678206847778818/N49v0BTq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/811678206847778818/N49v0BTq_normal.jpg',
#    'profile_link_color': '9E030B',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'ThatSpanishLady',
#    'statuses_count': 8374,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 900
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 20
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 4 new tweets, for a total of 4
# At 20 seconds, added 3 new tweets, for a total of 7
# At 40 seconds, added 2 new tweets, for a total of 9
# At 60 seconds, added 2 new tweets, for a total of 11
# At 80 seconds, added 2 new tweets, for a total of 13
# At 100 seconds, added 3 new tweets, for a total of 16
# At 120 seconds, added 0 new tweets, for a total of 16
# At 140 seconds, added 4 new tweets, for a total of 20
# At 160 seconds, added 4 new tweets, for a total of 24
# At 180 seconds, added 1 new tweets, for a total of 25
# At 200 seconds, added 2 new tweets, for a total of 27
# At 220 seconds, added 1 new tweets, for a total of 28
# At 240 seconds, added 3 new tweets, for a total of 31
# At 260 seconds, added 2 new tweets, for a total of 33
# At 280 seconds, added 2 new tweets, for a total of 35
# At 300 seconds, added 2 new tweets, for a total of 37
# At 320 seconds, added 1 new tweets, for a total of 38
# At 340 seconds, added 3 new tweets, for a total of 41
# At 360 seconds, added 1 new tweets, for a total of 42
# At 380 seconds, added 1 new tweets, for a total of 43
# At 400 seconds, added 4 new tweets, for a total of 47
# At 420 seconds, added 0 new tweets, for a total of 47
# At 440 seconds, added 1 new tweets, for a total of 48
# At 460 seconds, added 2 new tweets, for a total of 50
# At 480 seconds, added 2 new tweets, for a total of 52
# At 500 seconds, added 5 new tweets, for a total of 57
# At 520 seconds, added 4 new tweets, for a total of 61
# At 540 seconds, added 0 new tweets, for a total of 61
# At 560 seconds, added 3 new tweets, for a total of 64
# At 580 seconds, added 3 new tweets, for a total of 67
# At 600 seconds, added 1 new tweets, for a total of 68
# At 620 seconds, added 2 new tweets, for a total of 70
# At 640 seconds, added 1 new tweets, for a total of 71
# At 660 seconds, added 0 new tweets, for a total of 71
# At 680 seconds, added 3 new tweets, for a total of 74
# At 700 seconds, added 1 new tweets, for a total of 75
# At 720 seconds, added 2 new tweets, for a total of 77
# At 740 seconds, added 2 new tweets, for a total of 79
# At 760 seconds, added 2 new tweets, for a total of 81
# At 780 seconds, added 5 new tweets, for a total of 86
# At 800 seconds, added 1 new tweets, for a total of 87
# At 820 seconds, added 1 new tweets, for a total of 88
# At 840 seconds, added 1 new tweets, for a total of 89
# At 860 seconds, added 2 new tweets, for a total of 91
# At 880 seconds, added 2 new tweets, for a total of 93
# 93 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id   lat   lon  \
# 838948947506900992  838948947506900992  None  None
# 838948899117203456  838948899117203456  None  None
# 838948857916571650  838948857916571650  None  None
# 838948678907879425  838948678907879425  None  None
# 838949213614534660  838949213614534660  None  None
# 838949201501388800  838949201501388800  None  None
# 838949093028294656  838949093028294656  None  None
# 838949227841662977  838949227841662977  None  None
# 838949223873773570  838949223873773570  None  None
# 838949358250954755  838949358250954755  None  None
# 838949357730811914  838949357730811914  None  None
# 838949435983937536  838949435983937536  None  None
# 838949426743902210  838949426743902210  None  None
# 838949539512004608  838949539512004608  None  None
# 838949538396311552  838949538396311552  None  None
# 838949491701067776  838949491701067776  None  None
# 838949711902015489  838949711902015489  None  None
# 838949689869348865  838949689869348865  None  None
# 838949681279483904  838949681279483904  None  None
# 838949678758637570  838949678758637570  None  None
# 838949793456132100  838949793456132100  None  None
# 838949756118401024  838949756118401024  None  None
# 838949751383011328  838949751383011328  None  None
# 838949732441604097  838949732441604097  None  None
# 838949843087331328  838949843087331328  None  None
# 838949939833159680  838949939833159680  None  None
# 838949920619053056  838949920619053056  None  None
# 838950009215266818  838950009215266818  None  None
# 838950089959833601  838950089959833601  None  None
# 838950086331645953  838950086331645953  None  None
# ...                                ...   ...   ...
# 838951452047523840  838951452047523840  None  None
# 838951553071464448  838951553071464448  None  None
# 838949689869348865  {'created_at': 'Tue Mar 07 03:09:27 +0000 2017...
# 838949681279483904  {'created_at': 'Tue Mar 07 03:09:25 +0000 2017...
# 838949678758637570  {'created_at': 'Tue Mar 07 03:09:25 +0000 2017...
# 838949793456132100  {'created_at': 'Tue Mar 07 03:09:52 +0000 2017...
# 838949756118401024  {'created_at': 'Tue Mar 07 03:09:43 +0000 2017...
# 838949751383011328  {'created_at': 'Tue Mar 07 03:09:42 +0000 2017...
# 838949732441604097  {'created_at': 'Tue Mar 07 03:09:37 +0000 2017...
# 838949843087331328  {'created_at': 'Tue Mar 07 03:10:04 +0000 2017...
# 838949939833159680  {'created_at': 'Tue Mar 07 03:10:27 +0000 2017...
# 838949920619053056  {'created_at': 'Tue Mar 07 03:10:22 +0000 2017...
# 838950009215266818  {'created_at': 'Tue Mar 07 03:10:43 +0000 2017...
# 838950089959833601  {'created_at': 'Tue Mar 07 03:11:03 +0000 2017...
# 838950086331645953  {'created_at': 'Tue Mar 07 03:11:02 +0000 2017...
# ...                                                               ...
# 838951452047523840  {'created_at': 'Tue Mar 07 03:16:27 +0000 2017...
# 838951553071464448  {'created_at': 'Tue Mar 07 03:16:51 +0000 2017...
# 838951526185984000  {'created_at': 'Tue Mar 07 03:16:45 +0000 2017...
# 838951517877059584  {'created_at': 'Tue Mar 07 03:16:43 +0000 2017...
# 838951651335618560  {'created_at': 'Tue Mar 07 03:17:15 +0000 2017...
# 838951717463031808  {'created_at': 'Tue Mar 07 03:17:31 +0000 2017...
# 838951702380359681  {'created_at': 'Tue Mar 07 03:17:27 +0000 2017...
# 838951755522134016  {'created_at': 'Tue Mar 07 03:17:40 +0000 2017...
# 838951973785374720  {'created_at': 'Tue Mar 07 03:18:32 +0000 2017...
# 838951946484613120  {'created_at': 'Tue Mar 07 03:18:25 +0000 2017...
# 838951938028892163  {'created_at': 'Tue Mar 07 03:18:23 +0000 2017...
# 838952052457877513  {'created_at': 'Tue Mar 07 03:18:50 +0000 2017...
# 838952137472290820  {'created_at': 'Tue Mar 07 03:19:11 +0000 2017...
# 838952115607318528  {'created_at': 'Tue Mar 07 03:19:05 +0000 2017...
# 838952228723560449  {'created_at': 'Tue Mar 07 03:19:32 +0000 2017...
# 838952221828087808  {'created_at': 'Tue Mar 07 03:19:31 +0000 2017...
# 838952274714066944  {'created_at': 'Tue Mar 07 03:19:43 +0000 2017...
# 838952257475465216  {'created_at': 'Tue Mar 07 03:19:39 +0000 2017...
# 838952411465142277  {'created_at': 'Tue Mar 07 03:20:16 +0000 2017...
# 838952377591836672  {'created_at': 'Tue Mar 07 03:20:08 +0000 2017...
# 838952366804250624  {'created_at': 'Tue Mar 07 03:20:05 +0000 2017...
# 838952365705265152  {'created_at': 'Tue Mar 07 03:20:05 +0000 2017...
# 838952364170166273  {'created_at': 'Tue Mar 07 03:20:05 +0000 2017...
# 838952458126766080  {'created_at': 'Tue Mar 07 03:20:27 +0000 2017...
# 838952537780805633  {'created_at': 'Tue Mar 07 03:20:46 +0000 2017...
# 838951946484613120       none  Tue Mar 07 03:18:25 +0000 2017
# 838951938028892163       none  Tue Mar 07 03:18:23 +0000 2017
# 838952052457877513       none  Tue Mar 07 03:18:50 +0000 2017
# 838952137472290820       none  Tue Mar 07 03:19:11 +0000 2017
# 838952115607318528       none  Tue Mar 07 03:19:05 +0000 2017
# 838952228723560449       none  Tue Mar 07 03:19:32 +0000 2017
# 838952221828087808       none  Tue Mar 07 03:19:31 +0000 2017
# 838952274714066944       none  Tue Mar 07 03:19:43 +0000 2017
# 838952257475465216       none  Tue Mar 07 03:19:39 +0000 2017
# 838952411465142277       none  Tue Mar 07 03:20:16 +0000 2017
# 838952377591836672       none  Tue Mar 07 03:20:08 +0000 2017
# 838952366804250624       none  Tue Mar 07 03:20:05 +0000 2017
# 838952365705265152       none  Tue Mar 07 03:20:05 +0000 2017
# 838952364170166273       none  Tue Mar 07 03:20:05 +0000 2017
# 838952458126766080       none  Tue Mar 07 03:20:27 +0000 2017
# 838952537780805633       none  Tue Mar 07 03:20:46 +0000 2017
# 838952642047004672       none  Tue Mar 07 03:21:11 +0000 2017
# 838952730433634305       none  Tue Mar 07 03:21:32 +0000 2017
# 838952680659701760       none  Tue Mar 07 03:21:20 +0000 2017
# 838952796410032128       none  Tue Mar 07 03:21:48 +0000 2017
# 838952781302149120       none  Tue Mar 07 03:21:44 +0000 2017
#
# [93 rows x 9 columns]

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['Boston, MA', 'Washington, DC', 'North Andover, MA',
#        'Washington DC USA', '', 'Chicago', 'cash.me/$KeithBStill ',
#        'Saugus Ma', 'New Hampshire', 'Chicago, IL', 'London, England',
#        'Toronto, Ontario', 'Boston MA', 'Cambridge, MA', 'Burlington, MA',
#        'North Liberty, IA', 'Michigan, USA', 'BOSTON', 'Cambridge MA',
#        'Minnesota', 'Minnesota, USA', 'Reading, MA', 'ohio', 'Newton, MA',
#        'Somerville', 'Boston, USA', 'Medway, MA',
#        'Left is right in rural NE', 'uk', 'Massachusetts, USA',
#        'Alabama, USA', 'Medford, MA', 'Boston ', 'Arizona, USA',
#        'San Antonio, TX', 'Boulder, CO USA ', 'Pittsburgh, Pa',
#        'Freedonia', 'Greater Boston', 'Chelsea, MA',
#        'Beantown, Monsterchusetts', 'Banff Springs Hotel', 'Canada',
#        'around Boston', 'Non-national', 'Massachusetts', 'East Atlanta',
#        'Florida, USA', 'Smiths Falls, Ontario', '3RD ROCK FROM THE SUN',
#        'A field of Texas bluebonnets', 'the road to nowhere', 'Boston',
#        'Revere, MA', 'near Boston'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
variations_of_boston = ['Massachusetts, USA','Massachusetts','Boston, MA','Boston MA','BOSTON','Boston','Boston, USA','Boston ','Greater Boston','around Boston','Boston','near Boston']
df_tweets['location1']=df_tweets['location'].replace(variations_of_boston,'Boston, MA')
variations_of_dc=['Washington, DC','Washington DC USA']
df_tweets['location2']=df_tweets['location1'].replace(variations_of_dc,'Washington DC')
df_tweets['location3']=df_tweets['location2'].replace('^.*[Cc]ambridge.*$', 'Cambridge, MA', regex=True)
variations_of_minnesota=['Minnesota', 'Minnesota, USA']
df_tweets['location4']=df_tweets['location3'].replace(variations_of_minnesota, 'Minnesota')
df_tweets['location_final']=df_tweets['location4'].replace('^.*[Cc]hicago.*$', 'Chicago, IL',regex=True)
df_tweets['location_final'].unique()
# Out:
# array(['Boston, MA', 'Washington DC', 'North Andover, MA', '',
#        'Chicago, IL', 'cash.me/$KeithBStill ', 'Saugus Ma',
#        'New Hampshire', 'London, England', 'Toronto, Ontario',
#        'Cambridge, MA', 'Burlington, MA', 'North Liberty, IA',
#        'Michigan, USA', 'Minnesota', 'Reading, MA', 'ohio', 'Newton, MA',
#        'Somerville', 'Medway, MA', 'Left is right in rural NE', 'uk',
#        'Alabama, USA', 'Medford, MA', 'Arizona, USA', 'San Antonio, TX',
#        'Boulder, CO USA ', 'Pittsburgh, Pa', 'Freedonia', 'Chelsea, MA',
#        'Beantown, Monsterchusetts', 'Banff Springs Hotel', 'Canada',
#        'Non-national', 'East Atlanta', 'Florida, USA',
#        'Smiths Falls, Ontario', '3RD ROCK FROM THE SUN',
#        'A field of Texas bluebonnets', 'the road to nowhere', 'Revere, MA'], dtype=object)

# %%
grouped_tweets = df_tweets.groupby('location_final')
count_tweets = grouped_tweets['location_final'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                               Count
# Location
#                                  15
# 3RD ROCK FROM THE SUN             1
# A field of Texas bluebonnets      1
# Alabama, USA                      1
# Arizona, USA                      1
# Banff Springs Hotel               1
# Beantown, Monsterchusetts         1
# Boston, MA                       31
# Boulder, CO USA                   1
# Burlington, MA                    1
# Cambridge, MA                     4
# Canada                            1
# Chelsea, MA                       1
# Chicago, IL                       2
# East Atlanta                      1
# Florida, USA                      1
# Freedonia                         1
# Left is right in rural NE         1
# London, England                   1
# Medford, MA                       2
# Medway, MA                        1
# Michigan, USA                     1
# Minnesota                         2
# New Hampshire                     1
# Newton, MA                        1
# Non-national                      1
# North Andover, MA                 2
# North Liberty, IA                 1
# Pittsburgh, Pa                    1
# Reading, MA                       1
# Revere, MA                        1
# San Antonio, TX                   1
# Saugus Ma                         1
# Smiths Falls, Ontario             1
# Somerville                        1
# Toronto, Ontario                  1
# Washington DC                     2
# cash.me/$KeithBStill              1
# ohio                              1
# the road to nowhere               1
# uk                                1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#92f9d3",
"#fbbd86",
"#4dbcf5",
"#cca56e",
"#2fd2da",
"#ffd3d1",
"#56b7dd",
"#ffecc2",
"#a7dcff",
"#a3b27e",
"#8cb3c1",
"#c1fff1"]

# Create a pie chart
fig = plt.figure(figsize=(14,14))
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# Empty DataFrame
# Columns: [tweet_id, lat, lon, content, location, user, raw_source, data_point, time, location1, location_final, location_2, location2, location3, location4]
# Index: []

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# C:\Users\lhjbr\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# C:\Users\lhjbr\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
#    1893         if pre_doc is None:
#
# C:\Users\lhjbr\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# C:\Users\lhjbr\Anaconda3\lib\site-packages\matplotlib\cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
