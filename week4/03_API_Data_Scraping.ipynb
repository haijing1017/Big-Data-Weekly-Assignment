# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] 
# Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15

# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:15:00 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'youtu.be/D-jisH62PeQ?a',
#      'expanded_url': 'http://youtu.be/D-jisH62PeQ?a',
#      'indices': [60, 83],
#      'url': 'https://t.co/0Xnp71bphk'}],
#    'user_mentions': [{'id': 10228272,
#      'id_str': '10228272',
#      'indices': [88, 96],
#      'name': 'YouTube',
#      'screen_name': 'YouTube'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211212454264832,
#   'id_str': '838211212454264832',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   'text': 'New 2017 Nissan Rogue York PA Lancaster-Hanover, PA #26007: https://t.co/0Xnp71bphk via @YouTube',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Sep 30 14:46:02 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'We are a PA Nissan dealer offering New Nissan cars, trucks, Nissan Specials, Used car, Used Trucks for sale in York PA, Lancaster, Harrisburg, Hanover PA',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Apple-Nissan.com',
#        'expanded_url': 'http://Apple-Nissan.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/oVzh6FPCem'}]}},
#    'favourites_count': 6,
#    'follow_request_sent': None,
#    'followers_count': 22,
#    'following': None,
#    'friends_count': 18,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 78618553,
#    'id_str': '78618553',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'York, PA',
#    'name': 'Apple Nissan',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/78618553/1486046651',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/706950183452413953/5uDx5UKK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/706950183452413953/5uDx5UKK_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'applenissan',
#    'statuses_count': 2627,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/oVzh6FPCem',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:48 +0000 2017',
#   'entities': {'hashtags': [{'indices': [36, 43], 'text': 'UFC209'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211159165644800,
#   'id_str': '838211159165644800',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Fuck fuck FUUUUUCK THAT CUT IS DEEP #UFC209',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Aug 18 14:00:56 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Hockey Fan & Wrestling Mark',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'twitter.com/NHL/status/566…',
#        'expanded_url': 'https://twitter.com/NHL/status/566681158067695616?s=09',
#        'indices': [0, 23],
#        'url': 'https://t.co/5UsSwu3VBs'}]}},
#    'favourites_count': 8611,
#    'follow_request_sent': None,
#    'followers_count': 5291,
#    'following': None,
#    'friends_count': 635,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 179955168,
#    'id_str': '179955168',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 65,
#    'location': 'Hershey, PA',
#    'name': '(•_•)',
#    'notifications': None,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/536207248943378433/3WNi6ZkN.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/536207248943378433/3WNi6ZkN.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/179955168/1480125676',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/757427629636976640/kHVZzWcu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757427629636976640/kHVZzWcu_normal.jpg',
#    'profile_link_color': '1F98C7',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TylerKern27',
#    'statuses_count': 124410,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/5UsSwu3VBs',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:46 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'youtu.be/rRRhTUUBOm0?a',
#      'expanded_url': 'http://youtu.be/rRRhTUUBOm0?a',
#      'indices': [65, 88],
#      'url': 'https://t.co/fJis0KWK1x'}],
#    'user_mentions': [{'id': 10228272,
#      'id_str': '10228272',
#      'indices': [93, 101],
#      'name': 'YouTube',
#      'screen_name': 'YouTube'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211149892046849,
#   'id_str': '838211149892046849',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   'text': 'New 2017 Nissan Pathfinder York PA Lancaster-Hanover, PA #26022: https://t.co/fJis0KWK1x via @YouTube',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Sep 30 14:46:02 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'We are a PA Nissan dealer offering New Nissan cars, trucks, Nissan Specials, Used car, Used Trucks for sale in York PA, Lancaster, Harrisburg, Hanover PA',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Apple-Nissan.com',
#        'expanded_url': 'http://Apple-Nissan.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/oVzh6FPCem'}]}},
#    'favourites_count': 6,
#    'follow_request_sent': None,
#    'followers_count': 22,
#    'following': None,
#    'friends_count': 18,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 78618553,
#    'id_str': '78618553',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'York, PA',
#    'name': 'Apple Nissan',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/78618553/1486046651',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/706950183452413953/5uDx5UKK_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/706950183452413953/5uDx5UKK_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'applenissan',
#    'statuses_count': 2627,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/oVzh6FPCem',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': {'coordinates': [-76.4265, 40.3394], 'type': 'Point'},
#   'created_at': 'Sun Mar 05 02:14:45 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'untp.beer/s/c424567980',
#      'expanded_url': 'http://untp.beer/s/c424567980',
#      'indices': [70, 93],
#      'url': 'https://t.co/F3QuaPAWRx'}],
#    'user_mentions': [{'id': 2266731871,
#      'id_str': '2266731871',
#      'indices': [33, 48],
#      'name': 'Snitz Creek Brewery',
#      'screen_name': 'SnitzCreekBeer'},
#     {'id': 2266731871,
#      'id_str': '2266731871',
#      'indices': [52, 67],
#      'name': 'Snitz Creek Brewery',
#      'screen_name': 'SnitzCreekBeer'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': {'coordinates': [40.3394, -76.4265], 'type': 'Point'},
#   'id': 838211147627134978,
#   'id_str': '838211147627134978',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.450865, 40.319883],
#       [-76.391933, 40.319883],
#       [-76.391933, 40.355786],
#       [-76.450865, 40.355786]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Lebanon, PA',
#    'id': '3d66c4f797ae51e6',
#    'name': 'Lebanon',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3d66c4f797ae51e6.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://untappd.com" rel="nofollow">Untappd</a>',
#   'text': "Drinking a Mullen's Irish Red by @SnitzCreekBeer at @snitzcreekbeer — https://t.co/F3QuaPAWRx",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 25 23:34:07 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Avid saltwater fisherman, Captain with the Lebanon Fire Department. A bad day on the water beats any day at work',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 417,
#    'follow_request_sent': None,
#    'followers_count': 226,
#    'following': None,
#    'friends_count': 620,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 272159930,
#    'id_str': '272159930',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 15,
#    'location': 'Lebanon Pa',
#    'name': 'Stephen J Mendoff Jr',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/564928119304617985/DburQ5qg_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/564928119304617985/DburQ5qg_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'smendoffjr',
#    'statuses_count': 3548,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:43 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 163472298,
#      'id_str': '163472298',
#      'indices': [7, 16],
#      'name': 'Mykenna',
#      'screen_name': 'mykennaa'},
#     {'id': 1214225804,
#      'id_str': '1214225804',
#      'indices': [21, 33],
#      'name': '🤦🏽\u200d♀️',
#      'screen_name': 'lailababyyy'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211137518911489,
#   'id_str': '838211137518911489',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.786372, 40.263617],
#       [-76.748063, 40.263617],
#       [-76.748063, 40.276101],
#       [-76.786372, 40.276101]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Rutherford, PA',
#    'id': '644b884a2b7a0d3b',
#    'name': 'Rutherford',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/644b884a2b7a0d3b.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'i wish @mykennaa and @lailababyyy would pay attention to me ☹️',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed May 30 23:20:07 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "| cd east high c/o '17 🐾🎓 | | my boys are resting in heaven 🙏🏻❤️ | #OnePride 🦁🏈💙| don't dm me.",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 5824,
#    'follow_request_sent': None,
#    'followers_count': 1111,
#    'following': None,
#    'friends_count': 925,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 594991007,
#    'id_str': '594991007',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 8,
#    'location': 'somewhere being wild ',
#    'name': 'aubs ♉️🤘🏻',
#    'notifications': None,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000155534509/DUMrGh3z.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000155534509/DUMrGh3z.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/594991007/1488077740',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838099556428578816/4LkasBqj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838099556428578816/4LkasBqj_normal.jpg',
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ThatGirlAubreyy',
#    'statuses_count': 17998,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:43 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2612581062,
#      'id_str': '2612581062',
#      'indices': [0, 14],
#      'name': 'Hope',
#      'screen_name': 'sasha_rizzles'},
#     {'id': 1097298992,
#      'id_str': '1097298992',
#      'indices': [15, 28],
#      'name': 'Ƒяαηzι 🐇♀️',
#      'screen_name': 'franschkatic'},
#     {'id': 135272779,
#      'id_str': '135272779',
#      'indices': [29, 44],
#      'name': 'Sasha Alexander',
#      'screen_name': 'sashaalexander'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211137409810433,
#   'id_str': '838211137409810433',
#   'in_reply_to_screen_name': 'sasha_rizzles',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 2612581062,
#   'in_reply_to_user_id_str': '2612581062',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.931053, 40.249176],
#       [-76.890417, 40.249176],
#       [-76.890417, 40.277379],
#       [-76.931053, 40.277379]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Wormleysburg, PA',
#    'id': 'd3120e137f21e654',
#    'name': 'Wormleysburg',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/d3120e137f21e654.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'text': "@sasha_rizzles @franschkatic @sashaalexander Sasha's stalker weirdo is back again! He just posted on her IG! This guy has to be stopped! 😡",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Oct 20 23:41:25 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Breast Cancer Survivor! Loving Aunt to 11 nieces and nephews!  Cat mom to my spoiled Riley. LOVE Rizzoli & Isles! LOVE Angie Harmon & Sasha Alexander',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 30014,
#    'follow_request_sent': None,
#    'followers_count': 309,
#    'following': None,
#    'friends_count': 819,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 1976808385,
#    'id_str': '1976808385',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 10,
#    'location': 'Camp Hill, PA',
#    'name': 'Mary Miller',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/649354423953657857/81Ziz9G9_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/649354423953657857/81Ziz9G9_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mlmiller1959',
#    'statuses_count': 8165,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:41 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'youtu.be/qRdTn14a2fw?a',
#      'expanded_url': 'http://youtu.be/qRdTn14a2fw?a',
#      'indices': [44, 67],
#      'url': 'https://t.co/9k8MD8D97Z'}],
#    'user_mentions': [{'id': 10228272,
#      'id_str': '10228272',
#      'indices': [10, 18],
#      'name': 'YouTube',
#      'screen_name': 'YouTube'},
#     {'id': 16794568,
#      'id_str': '16794568',
#      'indices': [30, 43],
#      'name': 'Joey Graceffa',
#      'screen_name': 'JoeyGraceffa'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211131491635200,
#   'id_str': '838211131491635200',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.google.com/" rel="nofollow">Google</a>',
#   'text': 'I liked a @YouTube video from @joeygraceffa https://t.co/9k8MD8D97Z GALAXY SLIME PINTEREST DIY!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Dec 24 20:04:10 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "Just a kid with big dreams, of meeting Septiplier, Dwako, and Razz and I'm happy. because of them.",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'youtube.com/channel/UC3cnq…',
#        'expanded_url': 'https://www.youtube.com/channel/UC3cnqq0dG63JxsCpg4pJuzQ',
#        'indices': [0, 23],
#        'url': 'https://t.co/3wDtBcSl3o'}]}},
#    'favourites_count': 2458,
#    'follow_request_sent': None,
#    'followers_count': 80,
#    'following': None,
#    'friends_count': 52,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 4592631616,
#    'id_str': '4592631616',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'Carlisle, PA',
#    'name': 'DwakoSeptiplierFan1',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4592631616/1484438193',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/820419002723954688/yBi6lFMJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820419002723954688/yBi6lFMJ_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'Michael5SOSBoss',
#    'statuses_count': 2877,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/3wDtBcSl3o',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:40 +0000 2017',
#   'entities': {'hashtags': [{'indices': [40, 45], 'text': 'only'},
#     {'indices': [57, 64], 'text': 'LivePD'}],
#    'media': [{'display_url': 'pic.twitter.com/cOlCdvqiLi',
#      'expanded_url': 'https://twitter.com/LuftMarc/status/838210804046512128/photo/1',
#      'id': 838210800129097730,
#      'id_str': '838210800129097730',
#      'indices': [65, 88],
#      'media_url': 'http://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'sizes': {'large': {'h': 165, 'resize': 'fit', 'w': 310},
#       'medium': {'h': 165, 'resize': 'fit', 'w': 310},
#       'small': {'h': 165, 'resize': 'fit', 'w': 310},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838210804046512128,
#      'source_status_id_str': '838210804046512128',
#      'source_user_id': 3145426179,
#      'source_user_id_str': '3145426179',
#      'type': 'photo',
#      'url': 'https://t.co/cOlCdvqiLi'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3145426179,
#      'id_str': '3145426179',
#      'indices': [3, 12],
#      'name': 'First-time longtime',
#      'screen_name': 'LuftMarc'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/cOlCdvqiLi',
#      'expanded_url': 'https://twitter.com/LuftMarc/status/838210804046512128/photo/1',
#      'id': 838210800129097730,
#      'id_str': '838210800129097730',
#      'indices': [65, 88],
#      'media_url': 'http://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'sizes': {'large': {'h': 165, 'resize': 'fit', 'w': 310},
#       'medium': {'h': 165, 'resize': 'fit', 'w': 310},
#       'small': {'h': 165, 'resize': 'fit', 'w': 310},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838210804046512128,
#      'source_status_id_str': '838210804046512128',
#      'source_user_id': 3145426179,
#      'source_user_id_str': '3145426179',
#      'type': 'photo',
#      'url': 'https://t.co/cOlCdvqiLi'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211125934174208,
#   'id_str': '838211125934174208',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 02:13:23 +0000 2017',
#    'entities': {'hashtags': [{'indices': [26, 31], 'text': 'only'},
#      {'indices': [43, 50], 'text': 'LivePD'}],
#     'media': [{'display_url': 'pic.twitter.com/cOlCdvqiLi',
#       'expanded_url': 'https://twitter.com/LuftMarc/status/838210804046512128/photo/1',
#       'id': 838210800129097730,
#       'id_str': '838210800129097730',
#       'indices': [51, 74],
#       'media_url': 'http://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#       'sizes': {'large': {'h': 165, 'resize': 'fit', 'w': 310},
#        'medium': {'h': 165, 'resize': 'fit', 'w': 310},
#        'small': {'h': 165, 'resize': 'fit', 'w': 310},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/cOlCdvqiLi'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/cOlCdvqiLi',
#       'expanded_url': 'https://twitter.com/LuftMarc/status/838210804046512128/photo/1',
#       'id': 838210800129097730,
#       'id_str': '838210800129097730',
#       'indices': [51, 74],
#       'media_url': 'http://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#       'sizes': {'large': {'h': 165, 'resize': 'fit', 'w': 310},
#        'medium': {'h': 165, 'resize': 'fit', 'w': 310},
#        'small': {'h': 165, 'resize': 'fit', 'w': 310},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/cOlCdvqiLi'}]},
#    'favorite_count': 4,
#    'favorited': False,
#    'geo': None,
#    'id': 838210804046512128,
#    'id_str': '838210804046512128',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'What will he find tonight #only in Arizona #LivePD https://t.co/cOlCdvqiLi',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 07 20:52:28 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '❤️ Mike Calta, DP Show and LivePD',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 778,
#     'follow_request_sent': None,
#     'followers_count': 19,
#     'following': None,
#     'friends_count': 103,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 3145426179,
#     'id_str': '3145426179',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': 'Harrisburg PA',
#     'name': 'First-time longtime',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3145426179/1444226222',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/613002975036882944/V7vwnMlg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/613002975036882944/V7vwnMlg_normal.jpg',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'LuftMarc',
#     'statuses_count': 487,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @LuftMarc: What will he find tonight #only in Arizona #LivePD https://t.co/cOlCdvqiLi',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jan 16 19:56:19 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Enjoy reality TV, extreme weather fanatic, love to laugh !  #CowboysNation',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 4270,
#    'follow_request_sent': None,
#    'followers_count': 489,
#    'following': None,
#    'friends_count': 733,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 19082207,
#    'id_str': '19082207',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 28,
#    'location': 'Texas',
#    'name': 'Jennifer',
#    'notifications': None,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/682382602234380289/enRNHMvO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/682382602234380289/enRNHMvO_normal.jpg',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '5ED4DC',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'texasgem0',
#    'statuses_count': 1192,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:35 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'ycpspartans.com/x/ma6mv',
#      'expanded_url': 'http://www.ycpspartans.com/x/ma6mv',
#      'indices': [83, 106],
#      'url': 'https://t.co/c1g44eRDJt'}],
#    'user_mentions': [{'id': 125742109,
#      'id_str': '125742109',
#      'indices': [3, 16],
#      'name': 'York College Sports',
#      'screen_name': 'YCPathletics'},
#     {'id': 2771447825,
#      'id_str': '2771447825',
#      'indices': [18, 30],
#      'name': 'YCPSoftball',
#      'screen_name': 'YCPSoftball'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211107642802176,
#   'id_str': '838211107642802176',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 04 23:33:58 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'ycpspartans.com/x/ma6mv',
#       'expanded_url': 'http://www.ycpspartans.com/x/ma6mv',
#       'indices': [65, 88],
#       'url': 'https://t.co/c1g44eRDJt'}],
#     'user_mentions': [{'id': 2771447825,
#       'id_str': '2771447825',
#       'indices': [0, 12],
#       'name': 'YCPSoftball',
#       'screen_name': 'YCPSoftball'}]},
#    'favorite_count': 8,
#    'favorited': False,
#    'geo': None,
#    'id': 838170684996071424,
#    'id_str': '838170684996071424',
#    'in_reply_to_screen_name': 'YCPSoftball',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 2771447825,
#    'in_reply_to_user_id_str': '2771447825',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://www.prestosports.com" rel="nofollow">PrestoSports</a>',
#    'text': '@YCPSoftball York Leaves Florida With Two More Blowout Victories https://t.co/c1g44eRDJt',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Mar 23 18:38:07 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The official page for York College Athletics. Check out our Facebook page: https://t.co/Z5EzgiKnk0 #LetsGoYork',
#     'entities': {'description': {'urls': [{'display_url': 'facebook.com/YCPathletics',
#         'expanded_url': 'https://www.facebook.com/YCPathletics',
#         'indices': [75, 98],
#         'url': 'https://t.co/Z5EzgiKnk0'}]},
#      'url': {'urls': [{'display_url': 'ycpspartans.com',
#         'expanded_url': 'http://www.ycpspartans.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/uM4JtDRo2d'}]}},
#     'favourites_count': 809,
#     'follow_request_sent': None,
#     'followers_count': 3306,
#     'following': None,
#     'friends_count': 253,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 125742109,
#     'id_str': '125742109',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 36,
#     'location': 'York, Pa.',
#     'name': 'York College Sports',
#     'notifications': None,
#     'profile_background_color': '077F30',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000176538925/MKfeQN3u.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000176538925/MKfeQN3u.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/125742109/1463154551',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/428173053269262336/2T6-_Hd7_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/428173053269262336/2T6-_Hd7_normal.jpeg',
#     'profile_link_color': '0000FF',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'C1D1C3',
#     'profile_text_color': '194A24',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'YCPathletics',
#     'statuses_count': 12385,
#     'time_zone': 'Quito',
#     'translator_type': 'none',
#     'url': 'https://t.co/uM4JtDRo2d',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @YCPathletics: @YCPSoftball York Leaves Florida With Two More Blowout Victories https://t.co/c1g44eRDJt',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Dec 13 02:28:26 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Hakuna Matata',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1904,
#    'follow_request_sent': None,
#    'followers_count': 352,
#    'following': None,
#    'friends_count': 505,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 435447521,
#    'id_str': '435447521',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'Abee Battiste',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/435447521/1485796612',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/826116980532998146/zjp5y-dB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826116980532998146/zjp5y-dB_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ABeeC_s',
#    'statuses_count': 7027,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -21600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:32 +0000 2017',
#   'entities': {'hashtags': [{'indices': [27, 41], 'text': 'CPIHLplayoffs'}],
#    'media': [{'display_url': 'pic.twitter.com/3jKQUXefSe',
#      'expanded_url': 'https://twitter.com/CPIHLOfficial/status/838211091658334208/photo/1',
#      'id': 838211082980319233,
#      'id_str': '838211082980319233',
#      'indices': [42, 65],
#      'media_url': 'http://pbs.twimg.com/media/C6HsiffWYAEFX7J.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HsiffWYAEFX7J.jpg',
#      'sizes': {'large': {'h': 1498, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 878, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 497, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/3jKQUXefSe'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/3jKQUXefSe',
#      'expanded_url': 'https://twitter.com/CPIHLOfficial/status/838211091658334208/photo/1',
#      'id': 838211082980319233,
#      'id_str': '838211082980319233',
#      'indices': [42, 65],
#      'media_url': 'http://pbs.twimg.com/media/C6HsiffWYAEFX7J.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HsiffWYAEFX7J.jpg',
#      'sizes': {'large': {'h': 1498, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 878, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 497, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/3jKQUXefSe'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211091658334208,
#   'id_str': '838211091658334208',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.689419, 40.246151],
#       [-76.601027, 40.246151],
#       [-76.601027, 40.302317],
#       [-76.689419, 40.302317]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Hershey, PA',
#    'id': '8647282dba1cee1e',
#    'name': 'Hershey',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/8647282dba1cee1e.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'We have the happiest fans! #CPIHLplayoffs https://t.co/3jKQUXefSe',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Nov 03 11:36:53 +0000 2016',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'This is the new and official Twitter feed of the Central Pennsylvania Interscholastic Hockey League. Follow us for updates on the 2016-17 hockey season.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'CPIHL.com',
#        'expanded_url': 'http://www.CPIHL.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/AyrVZsuoRB'}]}},
#    'favourites_count': 62,
#    'follow_request_sent': None,
#    'followers_count': 146,
#    'following': None,
#    'friends_count': 12,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 794141293966487552,
#    'id_str': '794141293966487552',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Pennsylvania, USA',
#    'name': 'CPIHL Hockey',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/794143643443613696/00e59p8p_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/794143643443613696/00e59p8p_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'CPIHLOfficial',
#    'statuses_count': 293,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/AyrVZsuoRB',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:30 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 95943762,
#      'id_str': '95943762',
#      'indices': [0, 14],
#      'name': 'Tariq Noor Khan',
#      'screen_name': 'tariqnoorkhan'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211082946768900,
#   'id_str': '838211082946768900',
#   'in_reply_to_screen_name': 'tariqnoorkhan',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 95943762,
#   'in_reply_to_user_id_str': '95943762',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#   'text': '@tariqnoorkhan Thanks for following!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 21 07:35:12 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Proud father of 3, husband, Penn State University Alumni, christian, identical twin, and fan of  Nittany Lions football.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'linkedin.com/in/blainelthom…',
#        'expanded_url': 'https://www.linkedin.com/in/blainelthomas',
#        'indices': [0, 23],
#        'url': 'https://t.co/b4FKcufPBO'}]}},
#    'favourites_count': 364,
#    'follow_request_sent': None,
#    'followers_count': 681,
#    'following': None,
#    'friends_count': 1776,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 837238388,
#    'id_str': '837238388',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 28,
#    'location': 'Lebanon, Pennsylvania',
#    'name': 'Blaine Thomas',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/586589768806350848/vIyp7C3I.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/586589768806350848/vIyp7C3I.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/837238388/1487370369',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/797897088331812868/SDaBqs_M_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/797897088331812868/SDaBqs_M_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '333333',
#    'profile_sidebar_fill_color': '0084B4',
#    'profile_text_color': 'DDEEF6',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'AcctgBkgServ',
#    'statuses_count': 1458,
#    'time_zone': 'Atlantic Time (Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/b4FKcufPBO',
#    'utc_offset': -14400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:29 +0000 2017',
#   'entities': {'hashtags': [{'indices': [40, 45], 'text': 'only'},
#     {'indices': [57, 64], 'text': 'LivePD'}],
#    'media': [{'display_url': 'pic.twitter.com/cOlCdvqiLi',
#      'expanded_url': 'https://twitter.com/LuftMarc/status/838210804046512128/photo/1',
#      'id': 838210800129097730,
#      'id_str': '838210800129097730',
#      'indices': [65, 88],
#      'media_url': 'http://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'sizes': {'large': {'h': 165, 'resize': 'fit', 'w': 310},
#       'medium': {'h': 165, 'resize': 'fit', 'w': 310},
#       'small': {'h': 165, 'resize': 'fit', 'w': 310},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838210804046512128,
#      'source_status_id_str': '838210804046512128',
#      'source_user_id': 3145426179,
#      'source_user_id_str': '3145426179',
#      'type': 'photo',
#      'url': 'https://t.co/cOlCdvqiLi'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3145426179,
#      'id_str': '3145426179',
#      'indices': [3, 12],
#      'name': 'First-time longtime',
#      'screen_name': 'LuftMarc'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/cOlCdvqiLi',
#      'expanded_url': 'https://twitter.com/LuftMarc/status/838210804046512128/photo/1',
#      'id': 838210800129097730,
#      'id_str': '838210800129097730',
#      'indices': [65, 88],
#      'media_url': 'http://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HsSByXQAIu9cq.jpg',
#      'sizes': {'large': {'h': 165, 'resize': 'fit', 'w': 310},
#       'medium': {'h': 165, 'resize': 'fit', 'w': 310},
#       'small': {'h': 165, 'resize': 'fit', 'w': 310},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 838210804046512128,
#      'source_status_id_str': '838210804046512128',
#      'source_user_id': 3145426179,
#      'source_user_id_str': '3145426179',
#      'type': 'photo',
#      'url': 'https://t.co/cOlCdvqiLi'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211081537474560,
#   'id_str': '838211081537474560',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
# ...
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3145426179/1444226222',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/613002975036882944/V7vwnMlg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/613002975036882944/V7vwnMlg_normal.jpg',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'LuftMarc',
#     'statuses_count': 487,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @LuftMarc: What will he find tonight #only in Arizona #LivePD https://t.co/cOlCdvqiLi',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Dec 04 15:51:17 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 93,
#    'follow_request_sent': None,
#    'followers_count': 47,
#    'following': None,
#    'friends_count': 981,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 94583572,
#    'id_str': '94583572',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Boston',
#    'name': 'Mikethebig69',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/94583572/1403012917',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/481655325012271104/ninAGAFY_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/481655325012271104/ninAGAFY_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mikepop69',
#    'statuses_count': 511,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:27 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838211073400586240,
#   'id_str': '838211073400586240',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'When will I glo up tho',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 26 03:48:51 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "•'cause I'm with you 'till the end of the line• •06/26/2013•09/12/2015•05/18/2016• #BlackLivesMatter #PSU19",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'muse.theodysseyonline.com/author/rachell…',
#        'expanded_url': 'https://muse.theodysseyonline.com/author/rachellong2',
#        'indices': [0, 23],
#        'url': 'https://t.co/p9vhxQNt3G'}]}},
#    'favourites_count': 6704,
#    'follow_request_sent': None,
#    'followers_count': 2812,
#    'following': None,
#    'friends_count': 1624,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 159709745,
#    'id_str': '159709745',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en-gb',
#    'listed_count': 23,
#    'location': 'Middletown, PA',
#    'name': 'rachelann',
#    'notifications': None,
#    'profile_background_color': '9266CC',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/576178524945444864/kUtNSjMQ.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/576178524945444864/kUtNSjMQ.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/159709745/1488426680',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837146324470484994/k7cZbETt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837146324470484994/k7cZbETt_normal.jpg',
#    'profile_link_color': '992266',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '99CC33',
#    'profile_text_color': '3E4415',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ethereal_liam',
#    'statuses_count': 70572,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'https://t.co/p9vhxQNt3G',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:03 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3010896556,
#      'id_str': '3010896556',
#      'indices': [0, 16],
#      'name': 'Courtney B',
#      'screen_name': 'BeautifulWon210'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838210972540108802,
#   'id_str': '838210972540108802',
#   'in_reply_to_screen_name': 'BeautifulWon210',
#   'in_reply_to_status_id': 838207548473892867,
#   'in_reply_to_status_id_str': '838207548473892867',
#   'in_reply_to_user_id': 3010896556,
#   'in_reply_to_user_id_str': '3010896556',
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@BeautifulWon210 ❤️',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 02 03:24:18 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Iowa State Wide Receiver | Instagram: mech717',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'm.youtube.com/watch?v=nCIsyP…',
#        'expanded_url': 'https://m.youtube.com/watch?v=nCIsyPLcbe4',
#        'indices': [0, 23],
#        'url': 'https://t.co/wySGlGg4nr'}]}},
#    'favourites_count': 189,
#    'follow_request_sent': None,
#    'followers_count': 1630,
#    'following': None,
#    'friends_count': 380,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 291492916,
#    'id_str': '291492916',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Harrisburg, Pa',
#    'name': 'Amechie Walker Jr.',
#    'notifications': None,
#    'profile_background_color': 'EBEBEB',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/566410898/ua2x5444ogi4he8kttl2.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/566410898/ua2x5444ogi4he8kttl2.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/291492916/1452653858',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/754860573737623552/h82vPQhT_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/754860573737623552/h82vPQhT_normal.jpg',
#    'profile_link_color': '990000',
#    'profile_sidebar_border_color': 'DFDFDF',
#    'profile_sidebar_fill_color': 'F3F3F3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'awalkerr6',
#    'statuses_count': 24622,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'https://t.co/wySGlGg4nr',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 02:14:02 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 357054072,
#      'id_str': '357054072',
#      'indices': [3, 16],
#      'name': 'Cumberlink Sports',
#      'screen_name': 'Clink_Sports'},
#     {'id': 3483270497,
#      'id_str': '3483270497',
#      'indices': [42, 55],
#      'name': 'BoS wrestling',
#      'screen_name': 'wrestling_bs'},
#     {'id': 613043965,
#      'id_str': '613043965',
#      'indices': [78, 92],
#      'name': 'Camp Hill Athletics',
#      'screen_name': 'GoCHAthletics'},
#     {'id': 1665706190,
#      'id_str': '1665706190',
#      'indices': [94, 109],
#      'name': 'Trinity High Sports',
#      'screen_name': 'THSRocksSports'},
#     {'id': 3428403084,
#      'id_str': '3428403084',
#      'indices': [121, 134],
#      'name': 'Brett Keener',
#      'screen_name': 'brett_keener'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838210966353547264,
#   'id_str': '838210966353547264',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 02:02:54 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/838208163958702080',
#       'indices': [104, 127],
#       'url': 'https://t.co/cYqTqSc3y5'}],
#     'user_mentions': [{'id': 3483270497,
#       'id_str': '3483270497',
#       'indices': [24, 37],
#       'name': 'BoS wrestling',
#       'screen_name': 'wrestling_bs'},
#      {'id': 613043965,
#       'id_str': '613043965',
#       'indices': [60, 74],
#       'name': 'Camp Hill Athletics',
#       'screen_name': 'GoCHAthletics'},
#      {'id': 1665706190,
#       'id_str': '1665706190',
#       'indices': [76, 91],
#       'name': 'Trinity High Sports',
#       'screen_name': 'THSRocksSports'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 838208163958702080,
#    'id_str': '838208163958702080',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'PIAA REGIONAL WRESTLING\n@wrestling_bs sends trio to states; @GoCHAthletics, @THSRocksSports send 1, by… https://t.co/cYqTqSc3y5',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Aug 17 19:36:31 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Email: sportsdoor@cumberlink.com\nPhone: 240-7106\nFacebook: clinksports\nCovering sports in Cumberland County every day. College commit? Tell us on our website.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'cumberlink.com/sports',
#         'expanded_url': 'http://www.cumberlink.com/sports',
#         'indices': [0, 23],
#         'url': 'https://t.co/kn1YGlM2O5'}]}},
#     'favourites_count': 28,
#     'follow_request_sent': None,
#     'followers_count': 1742,
#     'following': None,
#     'friends_count': 53,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 357054072,
#     'id_str': '357054072',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 25,
#     'location': 'Carlisle, Pa.',
#     'name': 'Cumberlink Sports',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/357054072/1473300618',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1620894945/Badge_200x200_Twitter-Sports_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1620894945/Badge_200x200_Twitter-Sports_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Clink_Sports',
#     'statuses_count': 23940,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/kn1YGlM2O5',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @Clink_Sports: PIAA REGIONAL WRESTLING\n@wrestling_bs sends trio to states; @GoCHAthletics, @THSRocksSports send 1, by @brett_keener http…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Aug 12 18:15:13 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Coverage of Trinity HS sports from the students themselves. (The views of this Twitter account do not reflect the views of Trinity High School.)',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'thsrocks.us',
#        'expanded_url': 'http://www.thsrocks.us',
#        'indices': [0, 23],
#        'url': 'https://t.co/u2MXk3QdvG'}]}},
#    'favourites_count': 204,
#    'follow_request_sent': None,
#    'followers_count': 759,
#    'following': None,
#    'friends_count': 342,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 1665706190,
#    'id_str': '1665706190',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': 'Camp Hill, Pennsylvania',
#    'name': 'Trinity High Sports',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000160505223/3mCqGLLc.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000160505223/3mCqGLLc.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1665706190/1481409321',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/701784245014888448/jxzYjpKJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/701784245014888448/jxzYjpKJ_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'THSRocksSports',
#    'statuses_count': 1125,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/u2MXk3QdvG',
#    'utc_offset': -18000,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id      lat      lon  \
# 837044112897503238  837044112897503238     None     None
# 837044086590828549  837044086590828549     None     None
# 837044079158505472  837044079158505472     None     None
# 837044078743273472  837044078743273472     None     None
# 837044070010744832  837044070010744832     None     None
# 837044036976455681  837044036976455681     None     None
# 837044036456361984  837044036456361984     None     None
# 837044030793891840  837044030793891840     None     None
# 837044003128360961  837044003128360961     None     None
# 837044002591494144  837044002591494144     None     None
# 837043998384517120  837043998384517120     None     None
# 837043990591496192  837043990591496192     None     None
# 837043984933478400  837043984933478400     None     None
# 837043984920797185  837043984920797185     None     None
# 837043982249123841  837043982249123841     None     None
# 837044196557078529  837044196557078529     None     None
# 837044184955686913  837044184955686913     None     None
# 837044174792818689  837044174792818689     None     None
# 837044170917310464  837044170917310464     None     None
# 837044161928916996  837044161928916996     None     None
# 837044156010754052  837044156010754052     None     None
# 837044144983977985  837044144983977985     None     None
# 837044125019025408  837044125019025408     None     None
# 837044122326183936  837044122326183936 -76.8867  40.2732
#
#                                                               content  \
# 837044112897503238                           @DayLynnAcacia pfffft😂😂😂
# 837044086590828549  Soccer injuries are common. How can parents pr...
# 837044079158505472  @daniellewgal All the winning. Even the Cherry...
# 837044078743273472  These jewelry stores have a serious sexual har...
# 837044070010744832  We can't wait for Isaac’s Restaurants to open ...
# 837044036976455681  @SenToomey @POTUS I am sure that you do. You a...
# 837044036456361984                           @DayLynnAcacia lmaaooooo
# 837044030793891840  maybe if i stop getting my hopes up ill quit b...
# 837044003128360961                      @DR0girl wow they look great!
# 837044002591494144  What should I tell people to call me that don'...
# 837043998384517120  RT @SnowWhiteLion: @HoosierFooDog no one turns...
# 837043990591496192                          🍯 https://t.co/P2OSOaO6a2
# 837043984933478400  RT @bradonlongwx: Heavy rain photo from our ow...
# 837043984920797185  @phillydotcom: Pepsi to lay off 80 to 100, bla...
# 837043982249123841  RT @dkcookie37: @ThePensInsider https://t.co/O...
# 837044196557078529                                        WeisMarkets
# 837044184955686913  Registration for the 2017 Pathways for Victim ...
# 837044174792818689  RT @ProtectPAJobs: @phillydotcom: Pepsi to lay...
# 837044170917310464  @DavidDorn_VTTV @Twigolet @UKParliament Mr Nev...
# 837044161928916996  RT @abc27News: Man gets up to 11 years for ars...
# 837044156010754052  RT @GovernorTomWolf: Yes. My budget proposes c...
# 837044144983977985  RT @realJeffreyLord: The New York Times Fact C...
# 837044125019025408  I entered a giveaway for a chance to win "Amar...
# 837044122326183936  This #job might be a great fit for you: Truck ...
#
#                                     location                user  \
# 837044112897503238               violet hill          3327004786
# 837044086590828549         Mechanicsburg, PA  774290897504641024
# 837044079158505472                Harrisburg           326429245
# 837044078743273472               Lebanon, PA            75726223
# 837044070010744832                  York, PA            41597035
# 837044036976455681               Hershey, PA  826845237918236674
# 837044036456361984               violet hill          3327004786
# 837044030793891840            Harrisburg, Pa           393567280
# 837044003128360961                Lebanon,PA           110275598
# 837044002591494144               Hershey, PA  758718427724967936
# 837043998384517120   California BIIIIIIIHHHH  802287499561160704
# 837043990591496192              Annville, PA            48596967
# 837043984933478400                  York, PA             9544952
# 837043984920797185  Harrisburg, Pennsylvania           121231599
# 837043982249123841                                     453713178
# 837044196557078529                  York. Pa           141992501
# 837044184955686913            Harrisburg, PA          3302100449
# 837044174792818689             Harrisburg PA          3001459376
# 837044170917310464           North Cornwall           1322236688
# 837044161928916996           Cherokee County          2315600904
# 837044156010754052                                    2192026503
# 837044144983977985                            736670280303710208
# 837044125019025408              Annville pa           1401267374
# 837044122326183936                                     126380751
#
#                                                            raw_source  \
# 837044112897503238  {'created_at': 'Wed Mar 01 20:57:22 +0000 2017...
# 837044086590828549  {'created_at': 'Wed Mar 01 20:57:16 +0000 2017...
# 837044079158505472  {'created_at': 'Wed Mar 01 20:57:14 +0000 2017...
# 837044078743273472  {'created_at': 'Wed Mar 01 20:57:14 +0000 2017...
# 837044070010744832  {'created_at': 'Wed Mar 01 20:57:12 +0000 2017...
# 837044036976455681  {'created_at': 'Wed Mar 01 20:57:04 +0000 2017...
# 837044036456361984  {'created_at': 'Wed Mar 01 20:57:04 +0000 2017...
# 837044030793891840  {'created_at': 'Wed Mar 01 20:57:03 +0000 2017...
# 837044003128360961  {'created_at': 'Wed Mar 01 20:56:56 +0000 2017...
# 837044002591494144  {'created_at': 'Wed Mar 01 20:56:56 +0000 2017...
# 837043998384517120  {'created_at': 'Wed Mar 01 20:56:55 +0000 2017...
# 837043990591496192  {'created_at': 'Wed Mar 01 20:56:53 +0000 2017...
# 837043984933478400  {'created_at': 'Wed Mar 01 20:56:52 +0000 2017...
# 837043984920797185  {'created_at': 'Wed Mar 01 20:56:52 +0000 2017...
# 837043982249123841  {'created_at': 'Wed Mar 01 20:56:51 +0000 2017...
# 837044196557078529  {'created_at': 'Wed Mar 01 20:57:42 +0000 2017...
# 837044184955686913  {'created_at': 'Wed Mar 01 20:57:39 +0000 2017...
# 837044174792818689  {'created_at': 'Wed Mar 01 20:57:37 +0000 2017...
# 837044170917310464  {'created_at': 'Wed Mar 01 20:57:36 +0000 2017...
# 837044161928916996  {'created_at': 'Wed Mar 01 20:57:34 +0000 2017...
# 837044156010754052  {'created_at': 'Wed Mar 01 20:57:32 +0000 2017...
# 837044144983977985  {'created_at': 'Wed Mar 01 20:57:30 +0000 2017...
# 837044125019025408  {'created_at': 'Wed Mar 01 20:57:25 +0000 2017...
# 837044122326183936  {'created_at': 'Wed Mar 01 20:57:24 +0000 2017...
#
#                    data_point                            time
# 837044112897503238       none  Wed Mar 01 20:57:22 +0000 2017
# 837044086590828549       none  Wed Mar 01 20:57:16 +0000 2017
# 837044079158505472       none  Wed Mar 01 20:57:14 +0000 2017
# 837044078743273472       none  Wed Mar 01 20:57:14 +0000 2017
# 837044070010744832       none  Wed Mar 01 20:57:12 +0000 2017
# 837044036976455681       none  Wed Mar 01 20:57:04 +0000 2017
# 837044036456361984       none  Wed Mar 01 20:57:04 +0000 2017
# 837044030793891840       none  Wed Mar 01 20:57:03 +0000 2017
# 837044003128360961       none  Wed Mar 01 20:56:56 +0000 2017
# 837044002591494144       none  Wed Mar 01 20:56:56 +0000 2017
# 837043998384517120       none  Wed Mar 01 20:56:55 +0000 2017
# 837043990591496192       none  Wed Mar 01 20:56:53 +0000 2017
# 837043984933478400       none  Wed Mar 01 20:56:52 +0000 2017
# 837043984920797185       none  Wed Mar 01 20:56:52 +0000 2017
# 837043982249123841       none  Wed Mar 01 20:56:51 +0000 2017
# 837044196557078529       none  Wed Mar 01 20:57:42 +0000 2017
# 837044184955686913       none  Wed Mar 01 20:57:39 +0000 2017
# 837044174792818689       none  Wed Mar 01 20:57:37 +0000 2017
# 837044170917310464       none  Wed Mar 01 20:57:36 +0000 2017
# 837044161928916996       none  Wed Mar 01 20:57:34 +0000 2017
# 837044156010754052       none  Wed Mar 01 20:57:32 +0000 2017
# 837044144983977985       none  Wed Mar 01 20:57:30 +0000 2017
# 837044125019025408       none  Wed Mar 01 20:57:25 +0000 2017
# 837044122326183936       none  Wed Mar 01 20:57:24 +0000 2017

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
df_tweets['location'].
# Out:
# array(['violet hill', 'Mechanicsburg, PA', 'Harrisburg', 'Lebanon, PA',
#        'York, PA', 'Hershey, PA', 'Harrisburg, Pa', 'Lebanon,PA',
#        'California BIIIIIIIHHHH', 'Annville, PA',
#        'Harrisburg, Pennsylvania', '', 'York. Pa', 'Harrisburg, PA',
#        'Harrisburg PA', 'North Cornwall ', 'Cherokee County',
#        ' Annville pa '], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                           Count
# Location
#                               4
#  Annville pa                  1
# Annville, PA                  1
# California BIIIIIIIHHHH       1
# Cherokee County               1
# Harrisburg                    1
# Harrisburg PA                 1
# Harrisburg, PA                1
# Harrisburg, Pa                1
# Harrisburg, Pennsylvania      1
# Hershey, PA                   2
# Lebanon, PA                   1
# Lebanon,PA                    1
# Mechanicsburg, PA             1
# North Cornwall                1
# York, PA                      2
# York. Pa                      1
# violet hill                   2

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
#                               tweet_id      lat      lon  \
# 837044122326183936  837044122326183936 -76.8867  40.2732
#
#                                                               content  \
# 837044122326183936  This #job might be a great fit for you: Truck ...
#
#                    location       user  \
# 837044122326183936           126380751
#
#                                                            raw_source  \
# 837044122326183936  {'created_at': 'Wed Mar 01 20:57:24 +0000 2017...
#
#                    data_point                            time
# 837044122326183936       none  Wed Mar 01 20:57:24 +0000 2017

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')
# Out:
# 837044112897503238                 violet hill
# 837044086590828549           Mechanicsburg, PA
# 837044079158505472                  Harrisburg
# 837044078743273472                 Lebanon, PA
# 837044070010744832                    York, PA
# 837044036976455681                 Hershey, PA
# 837044036456361984                 violet hill
# 837044030793891840              Harrisburg, Pa
# 837044003128360961                  Lebanon,PA
# 837044002591494144                 Hershey, PA
# 837043998384517120     California BIIIIIIIHHHH
# 837043990591496192                Annville, PA
# 837043984933478400                    York, PA
# 837043984920797185    Harrisburg, Pennsylvania
# 837043982249123841
# 837044196557078529                    York. Pa
# 837044184955686913              Harrisburg, PA
# 837044174792818689               Harrisburg PA
# 837044170917310464             North Cornwall
# 837044161928916996             Cherokee County
# 837044156010754052
# 837044144983977985
# 837044125019025408                Annville pa
# 837044122326183936
# Name: location, dtype: object

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
